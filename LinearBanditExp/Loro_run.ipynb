# %%
for i in range (0, 30):
    # %run C:\Users\edoar\PycharmProjects\LinearBanditExp\Loro_algoritmo_(moltiplicazione)_Finale.ipynb
# Out:
# x 0 y 0 reward 1.8657369059294941
# x 0 y 1 reward 1.2608649821707276
# x 0 y 2 reward 1.928754279841597
# x 1 y 0 reward 1.58704753291395
# x 1 y 1 reward 1.076347003430258
# x 1 y 2 reward 1.8047624297747795
# x 2 y 0 reward 1.2340350670830822
# x 2 y 1 reward 0.8641384707846875
# x 2 y 2 reward 1.2759686040073401
# x 3 y 0 reward 1.6000794579717441
# x 3 y 1 reward 1.0672223881710157
# x 3 y 2 reward 1.612798982165239
# 1
# 1.2608649821707276
# 1
# 1
# 1
# 1
# index 0 lower_bound 1.310223773430478 mean 1.695903949613591 upper 2.081584125796704
# index 1 lower_bound 0.8141966407188945 mean 1.0705840628514296 upper 1.3269714849839647
# index 2 lower_bound 1.332320040184581 mean 1.7602000430340277 upper 2.1880800458834746
# index 3 lower_bound 1.052553178162272 mean 1.5024112728195915 upper 1.9522693674769112
# index 4 lower_bound 0.6534107981752952 mean 0.9486205647278365 upper 1.2438303312803778
# ...

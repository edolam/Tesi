# %%
for i in range (0, 30):
    # %run C:\Users\effel\Desktop\LinearBanditExp\Loro_algoritmo_(moltiplicazione)_Finale.ipynb
# Out:
# x 0 y 0 reward 1.2843416860269041
# x 0 y 1 reward 0.9989422914546447
# x 0 y 2 reward 2.1528876463220006
# x 1 y 0 reward 1.0616923407168557
# x 1 y 1 reward 0.7202245583411343
# x 1 y 2 reward 1.713111163218917
# x 2 y 0 reward 1.7192045239070501
# x 2 y 1 reward 1.377120664895553
# x 2 y 2 reward 2.8736447171007278
# x 3 y 0 reward 0.8454494341275968
# x 3 y 1 reward 0.6320325508800342
# x 3 y 2 reward 1.3804474944472214
# 7
# 1.377120664895553
# 1
# 1
# 1
# 1
# index 0 lower_bound 0.8908624281550296 mean 1.253725870404318 upper 1.6165893126536064
# index 1 lower_bound 0.6120997991939658 mean 0.9563201436730489 upper 1.3005404881521319
# index 2 lower_bound 1.5678671849508807 mean 1.9945631253331018 upper 2.421259065715323
# index 3 lower_bound 0.6749514498337752 mean 0.9890260392862442 upper 1.3031006287387132
# index 4 lower_bound 0.4592833801706895 mean 0.747961801008003 upper 1.0366402218453166
# ...

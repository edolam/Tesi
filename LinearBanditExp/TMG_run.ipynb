# %%
for i in range (0, 30):
    # %run C:\Users\edoar\PycharmProjects\LinearBanditExp\Linear_Bandit_TMG_Finale.ipynb
# Out:
# 0 0 1.8657369059294944
# 0 1 1.2608649821707272
# 0 2 1.9287542798415973
# 1 0 1.5870475329139502
# 1 1 1.076347003430258
# 1 2 1.8047624297747795
# 2 0 1.2340350670830822
# 2 1 0.8641384707846875
# 2 2 1.2759686040073401
# 3 0 1.6000794579717441
# 3 1 1.0672223881710157
# 3 2 1.612798982165239
# 0
# 1.2608649821707272
# x 0 y 0
# x 1 y 0
# x 2 y 0
# x 2 y 0
# [1.8194388355749231, 1.2522940127638371, 1.9080984041119073, 1.5388213194167482, 1.0626452410568807, 1.8138016052628672, 1.10934347054224, 0.7124085898030894, 1.22905799929375, 1.873033754116386, 1.3083015939210123, 1.9506336126154438, 1.5327488434457686, 1.120578554441996, 1.7094163250211099, 1.1579125945437305, 0.9065222552424373, 1.1584216697197662, 1.6836767367682708, 1.1471851603618906, 1.6032023775610724, 2.0347037358632454, 1.4636218068042657, 2.0199284078381305, 1.602872371456513]
# [0, 0, 0, 1, 1, 1, 2, 2, 2, 0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 0, 1, 0, 1]
# [808, 245, 6, 566]
# [802, 0, 0, 0]
# ...
